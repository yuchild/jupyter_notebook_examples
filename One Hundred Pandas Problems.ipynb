# %% [markdown]
# ## One Hundred Pandas Problems
# From: https://github.com/ajcr/100-pandas-puzzles/blob/master/100-pandas-puzzles-with-solutions.ipynb

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '0.24.2'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.7.3.final.0
# python-bits: 64
# OS: Linux
# OS-release: 5.0.0-37-generic
# machine: x86_64
# processor: x86_64
# byteorder: little
# LC_ALL: None
# LANG: en_US.UTF-8
# LOCALE: en_US.UTF-8
#
# pandas: 0.24.2
# pytest: 4.3.1
# pip: 19.0.3
# setuptools: 40.8.0
# Cython: 0.29.6
# numpy: 1.16.2
# scipy: 1.2.1
# pyarrow: None
# xarray: None
# IPython: 7.4.0
# sphinx: 1.8.5
# patsy: 0.5.1
# dateutil: 2.8.0
# pytz: 2018.9
# blosc: None
# bottleneck: 1.2.1
# tables: 3.5.1
# numexpr: 2.6.9
# feather: None
# matplotlib: 3.0.3
# openpyxl: 2.6.1
# xlrd: 1.2.0
# xlwt: 1.3.0
# xlsxwriter: 1.1.5
# lxml.etree: 4.3.2
# bs4: 4.7.1
# html5lib: 1.0.1
# sqlalchemy: 1.3.1
# pymysql: None
# psycopg2: 2.7.6.1 (dt dec pq3 ext lo64)
# jinja2: 2.10
# s3fs: None
# fastparquet: None
# pandas_gbq: None
# pandas_datareader: None
# gcsfs: None

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(data, index=labels)

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
# animal      10 non-null object
# age         8 non-null float64
# visits      10 non-null int64
# priority    10 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %%
df.iloc[:3] # iloc i for index, which is a-j in this df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df.loc[:, ['animal', 'age']] # selects animal and age columns
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df[['animal', 'age']] # same as above
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df.loc[df.index[[3,4,8]], ['animal', 'age']] # rows 3, 4, 8, cols animal and age
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
df[df['visits'] > 3] # returns where visits > 3. which is none
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %%
df[df['age'].isnull()] # returns rows where age is null
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df[(df['animal'] == 'cat') & (df['age'] < 3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
df[df['age'].between(2,4)] # age betwen 2 and 4 inclusive
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
df.loc['f','age'] = 1.5 # changes f row and age to 1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df['visits'].sum() # adds up visits
# Out:
# 19

# %%
df.groupby('animal')['age'].mean() # groups animal categories and finds mean of each category
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %%
df.loc['k'] = [5.5, 'dg', 'no', 2] # adds entire row of k

# %%
df
# Out:
#   animal  age visits priority
# a    cat  2.5      1      yes
# b    cat    3      3      yes
# c  snake  0.5      2       no
# d    dog  NaN      3      yes
# e    dog    5      2       no
# f    cat  1.5      3       no
# g  snake  4.5      1       no
# h    cat  NaN      1      yes
# i    dog    7      2       no
# j    dog    3      1       no
# k    5.5   dg     no        2

# %%
df.drop('k') # drops row k
# Out:
#   animal  age visits priority
# a    cat  2.5      1      yes
# b    cat    3      3      yes
# c  snake  0.5      2       no
# d    dog  NaN      3      yes
# e    dog    5      2       no
# f    cat  1.5      3       no
# g  snake  4.5      1       no
# h    cat  NaN      1      yes
# i    dog    7      2       no
# j    dog    3      1       no

# %%
df['animal'].value_counts() # counts frequency of each animal
# Out:
# dog      4
# cat      4
# snake    2
# 5.5      1
# Name: animal, dtype: int64

# %%
df.sort_values(by=['age', 'visits'], ascending=[False, True])
# Out:
#   animal  age visits priority
# k    5.5   dg     no        2
# i    dog    7      2       no
# e    dog    5      2       no
# g  snake  4.5      1       no
# j    dog    3      1       no
# b    cat    3      3      yes
# a    cat  2.5      1      yes
# f    cat  1.5      3       no
# c  snake  0.5      2       no
# h    cat  NaN      1      yes
# d    dog  NaN      3      yes

# %%
df['priority'] = df['priority'].map({'yes': True, 'no': False})

# %%
# %%timeit
df['animal'] = df['animal'].replace('snake', 'python')
# Out:
# 402 µs ± 27.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df
# Out:
#    animal  age visits priority
# a     cat  2.5      1     True
# b     cat    3      3     True
# c  python  0.5      2    False
# d     dog  NaN      3     True
# e     dog    5      2    False
# f     cat  1.5      3    False
# g  python  4.5      1    False
# h     cat  NaN      1     True
# i     dog    7      2    False
# j     dog    3      1    False
# k     5.5   dg     no      NaN

# %%
# df.pivot_table(index='animal', columns='visits', values='age', aggfunc='mean')

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})

# %%
df
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   5
# 8   6
# 9   7
# 10  7

# %%
df.loc[df['A'].shift() != df['A']] # drops duplicates
# Out:
#    A
# 0  1
# 1  2
# 3  3
# 4  4
# 5  5
# 8  6
# 9  7

# %%
df.drop_duplicates(subset='A') # drops duplicates
# Out:
#    A
# 0  1
# 1  2
# 3  3
# 4  4
# 5  5
# 8  6
# 9  7

# %%
df = pd.DataFrame(np.random.random(size=(5,3)))
df
# Out:
#           0         1         2
# 0  0.101893  0.065434  0.431244
# 1  0.044797  0.133144  0.245838
# 2  0.725947  0.104563  0.449826
# 3  0.212160  0.886005  0.222840
# 4  0.311381  0.730180  0.582358

# %%
df.sub(df.mean(axis=1), axis=0) # subtact mean from each element
# Out:
#           0         1         2
# 0 -0.097631 -0.134090  0.231720
# 1 -0.096463 -0.008116  0.104579
# 2  0.299168 -0.322216  0.023047
# 3 -0.228175  0.445670 -0.217495
# 4 -0.229926  0.188874  0.041052

# %%
df.add(df.mean(axis=1), axis=0) # add mean to each element
# Out:
#           0         1         2
# 0  0.301417  0.264958  0.630768
# 1  0.186057  0.274404  0.387098
# 2  1.152726  0.531341  0.876605
# 3  0.652495  1.326340  0.663175
# 4  0.852687  1.271486  1.123665

# %%
df = pd.DataFrame(np.random.random(size=(5,10)), columns=list('abcdefghij'))
df
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.033698  0.451989  0.856553  0.656887  0.697992  0.933534  0.885163
# 1  0.119134  0.004515  0.510125  0.398857  0.956061  0.509346  0.333682
# 2  0.072417  0.927617  0.378037  0.991758  0.019149  0.180673  0.674109
# 3  0.290766  0.966343  0.598749  0.038079  0.158498  0.592067  0.989480
# 4  0.305410  0.444487  0.360054  0.025641  0.954633  0.098761  0.961091
#
#           h         i         j
# 0  0.705983  0.459905  0.053100
# 1  0.281161  0.686618  0.392659
# 2  0.943422  0.507744  0.254695
# 3  0.642332  0.276079  0.007372
# 4  0.198314  0.304117  0.444953

# %%
df.sum().idxmin() # returns the column name of the smallest sum
# Out:
# 'a'

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})
df
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   5
# 8   6
# 9   7
# 10  7

# %%
len(df) - df.duplicated(keep=False).sum() # counts number of duplicates
# Out:
# 4

# %%
df.A.value_counts() # can also see the summary of values
# Out:
# 5    3
# 7    2
# 2    2
# 6    1
# 4    1
# 3    1
# 1    1
# Name: A, dtype: int64

# %%
len(df.drop_duplicates(keep=False)) # counts number of duplicates
# Out:
# 4

# %%
df = pd.DataFrame({'A': [1, np.nan, 2, np.nan, 4, 5, np.nan, 5, np.nan, 7, np.nan]
                  , 'B': [np.nan, np.nan, 2, np.nan, 4, np.nan, 5, 5, 6, np.nan, 7]
                  , 'C': [np.nan, 2, 2, np.nan, 4, 5, np.nan, 5, np.nan, np.nan, 7]
                  , 'D': [1, np.nan, 2, np.nan, 4, 5, np.nan, np.nan, 6, 7, np.nan]
                  , 'E': [1, 2, np.nan, np.nan, np.nan, np.nan, np.nan, 5, 6, 7, 7]
                  , 'F': [np.nan, np.nan, np.nan, np.nan, np.nan, 5, 5, 5, 6, 7, 7]
                  , 'G': [1, np.nan, np.nan, 3, 4, 5, 5, 5, np.nan, np.nan, np.nan]
                  , 'H': [1, np.nan, 2, np.nan, np.nan, np.nan, np.nan, 5, 6, 7, 7]
                  , 'I': [1, np.nan, np.nan, np.nan, 4, 5, 5, 5, 6, np.nan, np.nan]
                  , 'J': [1, 2, np.nan, 3, 4, np.nan, 5, np.nan, np.nan, 7, np.nan]})
df
# Out:
#       A    B    C    D    E    F    G    H    I    J
# 0   1.0  NaN  NaN  1.0  1.0  NaN  1.0  1.0  1.0  1.0
# 1   NaN  NaN  2.0  NaN  2.0  NaN  NaN  NaN  NaN  2.0
# 2   2.0  2.0  2.0  2.0  NaN  NaN  NaN  2.0  NaN  NaN
# 3   NaN  NaN  NaN  NaN  NaN  NaN  3.0  NaN  NaN  3.0
# 4   4.0  4.0  4.0  4.0  NaN  NaN  4.0  NaN  4.0  4.0
# 5   5.0  NaN  5.0  5.0  NaN  5.0  5.0  NaN  5.0  NaN
# 6   NaN  5.0  NaN  NaN  NaN  5.0  5.0  NaN  5.0  5.0
# 7   5.0  5.0  5.0  NaN  5.0  5.0  5.0  5.0  5.0  NaN
# 8   NaN  6.0  NaN  6.0  6.0  6.0  NaN  6.0  6.0  NaN
# 9   7.0  NaN  NaN  7.0  7.0  7.0  NaN  7.0  NaN  7.0
# 10  NaN  7.0  7.0  NaN  7.0  7.0  NaN  7.0  NaN  NaN

# %%
(df.isnull().cumsum(axis=1) == 3).idxmax(axis=1) # finds the 3rd NaN value of each row
# Out:
# 0     F
# 1     D
# 2     G
# 3     C
# 4     H
# 5     H
# 6     D
# 7     A
# 8     G
# 9     G
# 10    G
# dtype: object

# %%
df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'), 
                   'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})
df
# Out:
#    grps  vals
# 0     a    12
# 1     a   345
# 2     a     3
# 3     b     1
# 4     b    45
# 5     c    14
# 6     a     4
# 7     a    52
# 8     b    54
# 9     c    23
# 10    c   235
# 11    c    21
# 12    b    57
# 13    b     3
# 14    c    87

# %%
df.groupby('grps')['vals'].nlargest(3).sum(level=0) # funds the sum of the 3 largest values in each group
# Out:
# grps
# a    409
# b    156
# c    345
# Name: vals, dtype: int64

# %%
df = pd.DataFrame({'A':np.arange(0,101)
                  , 'B':np.random.randint(0,2,101)})
df
# Out:
#        A  B
# 0      0  1
# 1      1  0
# 2      2  0
# 3      3  1
# 4      4  0
# 5      5  0
# 6      6  0
# 7      7  1
# 8      8  1
# 9      9  1
# 10    10  0
# 11    11  1
# 12    12  1
# 13    13  1
# 14    14  1
# 15    15  0
# 16    16  0
# 17    17  1
# 18    18  1
# 19    19  0
# 20    20  1
# 21    21  0
# 22    22  1
# 23    23  1
# 24    24  1
# 25    25  0
# 26    26  0
# 27    27  1
# 28    28  0
# 29    29  1
# ..   ... ..
# 71    71  0
# 72    72  0
# 73    73  1
# 74    74  1
# 75    75  0
# 76    76  1
# 77    77  0
# 78    78  1
# 79    79  1
# 80    80  0
# 81    81  1
# 82    82  0
# 83    83  0
# 84    84  1
# 85    85  0
# 86    86  1
# 87    87  1
# 88    88  0
# 89    89  1
# 90    90  0
# 91    91  1
# 92    92  1
# 93    93  0
# 94    94  1
# 95    95  1
# 96    96  1
# 97    97  1
# 98    98  1
# 99    99  0
# 100  100  0
#
# [101 rows x 2 columns]
